# %% [markdown]
# # CODE TO CLASSIFY TRAFFIC SIGNS USING LE-NET ARCHITECTURE IN KERAS

# %% [markdown]
# ## PROBLEM STATEMENT

# %% [markdown]
# - In this case study, you have been provided with images of traffic signs and the goal is to train a Deep Network to classify them
# - The dataset contains 43 different classes of images.
# - Classes are as listed below:
#
#     - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
#     - ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
#     - ( 4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
#     - ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
#     - ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
#     - (10, b'No passing for vehicles over 3.5 metric tons')
#     - (11, b'Right-of-way at the next intersection') (12, b'Priority road')
#     - (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
#     - (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
#     - (18, b'General caution') (19, b'Dangerous curve to the left')
#     - (20, b'Dangerous curve to the right') (21, b'Double curve')
#     - (22, b'Bumpy road') (23, b'Slippery road')
#     - (24, b'Road narrows on the right') (25, b'Road work')
#     - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
#     - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
#     - (31, b'Wild animals crossing')
#     - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
#     - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
#     - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
#     - (40, b'Roundabout mandatory') (41, b'End of no passing')
#     - (42, b'End of no passing by vehicles over 3.5 metric tons')
#
# - The network used is called Le-Net that was presented by Yann LeCun
# http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf

# %% [markdown]
# Citation
#
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
#
# @inproceedings{Stallkamp-IJCNN-2011,
#     author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel},
#     booktitle = {IEEE International Joint Conference on Neural Networks},
#     title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition},
#     year = {2011},
#     pages = {1453--1460}
# }

# %% [markdown]
# ## IMPORT LIBRARIES AND DATASET

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pickle
import warnings
import tensorflow as tf
warnings.filterwarnings("ignore")

# %%
# The pickle module implements binary protocols for serializing and de-serializing a Python object structure.
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape, X_test.shape, X_validation.shape
# Out:
# ((34799, 32, 32, 3), (12630, 32, 32, 3), (4410, 32, 32, 3))

# %%
y_train.shape, y_test.shape, y_validation.shape
# Out:
# ((34799,), (12630,), (4410,))

# %% [markdown]
# ## IMAGE EXPLORATION

# %%
i = 29666
plt.imshow(X_train[i])
plt.axis(False)
plt.show()
y_train[i]
# Out:
# 14

# %% [markdown]
# ## DATA PEPARATION

# %%
# Shuffle the dataset
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray.shape, X_test_gray.shape, X_validation_gray.shape
# Out:
# ((34799, 32, 32, 1), (12630, 32, 32, 1), (4410, 32, 32, 1))

# %%
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = 779
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap='gray')

# %% [markdown]
# ## MODEL TRAINING

# %% [markdown]
# The model consists of the following layers:
#
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#     - Input = 32x32x1
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
#
#     * Stride is the amount by which the kernel is shifted when the kernel is passed over the image.
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
# Import train_test_split from scikit library
from sklearn.model_selection import train_test_split

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(filters=6,
                     kernel_size=(5, 5),
                     activation='relu',
                     input_shape=(32,32,1)))
cnn_model.add(AveragePooling2D())

cnn_model.add(Conv2D(filters=6,
                     kernel_size=(5, 5),
                     activation='relu'))
cnn_model.add(AveragePooling2D())

cnn_model.add(Flatten())
cnn_model.add(Dense(units=120, activation='relu'))
cnn_model.add(Dense(units=84, activation='relu'))
cnn_model.add(Dense(units=43, activation = 'softmax'))

# %%
cnn_model.compile(optimizer=Adam(learning_rate=0.001), 
                  loss='sparse_categorical_crossentropy', 
                  metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=50,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 13s 188ms/step - loss: 3.3186 - accuracy: 0.1445 - val_loss: 3.0323 - val_accuracy: 0.2531
# Epoch 2/50
# 70/70 [==============================] - 12s 166ms/step - loss: 2.0004 - accuracy: 0.4648 - val_loss: 1.6758 - val_accuracy: 0.5190
# Epoch 3/50
# 70/70 [==============================] - 10s 141ms/step - loss: 1.1021 - accuracy: 0.6857 - val_loss: 1.1577 - val_accuracy: 0.6619
# Epoch 4/50
# 70/70 [==============================] - 10s 147ms/step - loss: 0.7787 - accuracy: 0.7788 - val_loss: 1.0074 - val_accuracy: 0.7039
# Epoch 5/50
# 70/70 [==============================] - 11s 150ms/step - loss: 0.6145 - accuracy: 0.8265 - val_loss: 0.8885 - val_accuracy: 0.7404
# Epoch 6/50
# 70/70 [==============================] - 10s 147ms/step - loss: 0.5211 - accuracy: 0.8558 - val_loss: 0.8242 - val_accuracy: 0.7667
# Epoch 7/50
# 70/70 [==============================] - 11s 156ms/step - loss: 0.4475 - accuracy: 0.8787 - val_loss: 0.8299 - val_accuracy: 0.7846
# Epoch 8/50
# 70/70 [==============================] - 10s 148ms/step - loss: 0.3973 - accuracy: 0.8919 - val_loss: 0.7738 - val_accuracy: 0.7943
# Epoch 9/50
# 70/70 [==============================] - 10s 145ms/step - loss: 0.3517 - accuracy: 0.9068 - val_loss: 0.7702 - val_accuracy: 0.7875
# Epoch 10/50
# 70/70 [==============================] - 10s 146ms/step - loss: 0.3166 - accuracy: 0.9166 - val_loss: 0.7126 - val_accuracy: 0.8091
# Epoch 11/50
# 70/70 [==============================] - 11s 155ms/step - loss: 0.2843 - accuracy: 0.9261 - val_loss: 0.6846 - val_accuracy: 0.8261
# Epoch 12/50
# 70/70 [==============================] - 10s 148ms/step - loss: 0.2563 - accuracy: 0.9360 - val_loss: 0.7121 - val_accuracy: 0.8129
# Epoch 13/50
# 70/70 [==============================] - 10s 142ms/step - loss: 0.2406 - accuracy: 0.9368 - val_loss: 0.7343 - val_accuracy: 0.8132
# Epoch 14/50
# 70/70 [==============================] - 10s 149ms/step - loss: 0.2191 - accuracy: 0.9445 - val_loss: 0.6897 - val_accuracy: 0.8263
# Epoch 15/50
# 70/70 [==============================] - 12s 178ms/step - loss: 0.2026 - accuracy: 0.9495 - val_loss: 0.6892 - val_accuracy: 0.8286
# Epoch 16/50
# 70/70 [==============================] - 14s 202ms/step - loss: 0.1926 - accuracy: 0.9511 - val_loss: 0.6572 - val_accuracy: 0.8331
# Epoch 17/50
# 70/70 [==============================] - 11s 158ms/step - loss: 0.1817 - accuracy: 0.9534 - val_loss: 0.6994 - val_accuracy: 0.8279
# Epoch 18/50
# 70/70 [==============================] - 10s 138ms/step - loss: 0.1672 - accuracy: 0.9576 - val_loss: 0.6905 - val_accuracy: 0.8224
# Epoch 19/50
# 70/70 [==============================] - 10s 136ms/step - loss: 0.1525 - accuracy: 0.9622 - val_loss: 0.7094 - val_accuracy: 0.8313
# Epoch 20/50
# 70/70 [==============================] - 10s 141ms/step - loss: 0.1478 - accuracy: 0.9625 - val_loss: 0.7392 - val_accuracy: 0.8306
# Epoch 21/50
# 70/70 [==============================] - 10s 138ms/step - loss: 0.1352 - accuracy: 0.9667 - val_loss: 0.7049 - val_accuracy: 0.8297
# Epoch 22/50
# 70/70 [==============================] - 10s 138ms/step - loss: 0.1314 - accuracy: 0.9663 - val_loss: 0.6932 - val_accuracy: 0.8438
# Epoch 23/50
# 70/70 [==============================] - 10s 141ms/step - loss: 0.1190 - accuracy: 0.9710 - val_loss: 0.7593 - val_accuracy: 0.8295
# Epoch 24/50
# 70/70 [==============================] - 10s 141ms/step - loss: 0.1151 - accuracy: 0.9714 - val_loss: 0.7241 - val_accuracy: 0.8415
# Epoch 25/50
# 70/70 [==============================] - 10s 139ms/step - loss: 0.1059 - accuracy: 0.9742 - val_loss: 0.7584 - val_accuracy: 0.8331
# Epoch 26/50
# 70/70 [==============================] - 10s 143ms/step - loss: 0.1058 - accuracy: 0.9737 - val_loss: 0.7400 - val_accuracy: 0.8463
# Epoch 27/50
# 70/70 [==============================] - 10s 142ms/step - loss: 0.0968 - accuracy: 0.9751 - val_loss: 0.7323 - val_accuracy: 0.8472
# Epoch 28/50
# 70/70 [==============================] - 10s 141ms/step - loss: 0.0912 - accuracy: 0.9764 - val_loss: 0.7885 - val_accuracy: 0.8467
# Epoch 29/50
# 70/70 [==============================] - 10s 146ms/step - loss: 0.0872 - accuracy: 0.9778 - val_loss: 0.7224 - val_accuracy: 0.8494
# Epoch 30/50
# 70/70 [==============================] - 10s 142ms/step - loss: 0.0787 - accuracy: 0.9806 - val_loss: 0.8305 - val_accuracy: 0.8381
# Epoch 31/50
# 70/70 [==============================] - 10s 150ms/step - loss: 0.0751 - accuracy: 0.9812 - val_loss: 0.7731 - val_accuracy: 0.8370
# Epoch 32/50
# 70/70 [==============================] - 10s 149ms/step - loss: 0.0728 - accuracy: 0.9817 - val_loss: 0.8123 - val_accuracy: 0.8431
# Epoch 33/50
# 70/70 [==============================] - 11s 153ms/step - loss: 0.0683 - accuracy: 0.9828 - val_loss: 0.8199 - val_accuracy: 0.8363
# Epoch 34/50
# 70/70 [==============================] - 11s 157ms/step - loss: 0.0637 - accuracy: 0.9835 - val_loss: 0.8329 - val_accuracy: 0.8451
# Epoch 35/50
# 70/70 [==============================] - 10s 146ms/step - loss: 0.0649 - accuracy: 0.9836 - val_loss: 0.8034 - val_accuracy: 0.8438
# Epoch 36/50
# 70/70 [==============================] - 10s 145ms/step - loss: 0.0604 - accuracy: 0.9844 - val_loss: 0.7829 - val_accuracy: 0.8376
# Epoch 37/50
# 70/70 [==============================] - 10s 138ms/step - loss: 0.0627 - accuracy: 0.9833 - val_loss: 0.8357 - val_accuracy: 0.8519
# Epoch 38/50
# 70/70 [==============================] - 10s 144ms/step - loss: 0.0547 - accuracy: 0.9860 - val_loss: 0.8680 - val_accuracy: 0.8497
# Epoch 39/50
# 70/70 [==============================] - 11s 162ms/step - loss: 0.0513 - accuracy: 0.9867 - val_loss: 0.8658 - val_accuracy: 0.8497
# Epoch 40/50
# 70/70 [==============================] - 12s 172ms/step - loss: 0.0484 - accuracy: 0.9881 - val_loss: 0.8433 - val_accuracy: 0.8537
# Epoch 41/50
# 70/70 [==============================] - 11s 158ms/step - loss: 0.0484 - accuracy: 0.9874 - val_loss: 0.9070 - val_accuracy: 0.8542
# Epoch 42/50
# 70/70 [==============================] - 11s 155ms/step - loss: 0.0510 - accuracy: 0.9865 - val_loss: 0.9103 - val_accuracy: 0.8415
# Epoch 43/50
# 70/70 [==============================] - 11s 153ms/step - loss: 0.0445 - accuracy: 0.9886 - val_loss: 0.9631 - val_accuracy: 0.8410
# Epoch 44/50
# 70/70 [==============================] - 10s 148ms/step - loss: 0.0448 - accuracy: 0.9882 - val_loss: 0.9444 - val_accuracy: 0.8397
# Epoch 45/50
# 70/70 [==============================] - 11s 151ms/step - loss: 0.0435 - accuracy: 0.9882 - val_loss: 0.9163 - val_accuracy: 0.8494
# Epoch 46/50
# 70/70 [==============================] - 10s 149ms/step - loss: 0.0363 - accuracy: 0.9910 - val_loss: 0.8691 - val_accuracy: 0.8449
# Epoch 47/50
# 70/70 [==============================] - 10s 147ms/step - loss: 0.0350 - accuracy: 0.9915 - val_loss: 0.9410 - val_accuracy: 0.8447
# Epoch 48/50
# 70/70 [==============================] - 11s 160ms/step - loss: 0.0343 - accuracy: 0.9916 - val_loss: 0.9207 - val_accuracy: 0.8510
# Epoch 49/50
# 70/70 [==============================] - 12s 173ms/step - loss: 0.0344 - accuracy: 0.9914 - val_loss: 0.9627 - val_accuracy: 0.8590
# Epoch 50/50
# 70/70 [==============================] - 12s 171ms/step - loss: 0.0389 - accuracy: 0.9891 - val_loss: 0.9318 - val_accuracy: 0.8537

# %% [markdown]
# ## MODEL EVALUATION

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.8595

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Get Predicted classes from pred_probs 
pred_probs = cnn_model(X_test_gray_norm)
y_preds = tf.argmax(pred_probs, axis=1)
y_preds
# Out:
# <tf.Tensor: shape=(12630,), dtype=int64, numpy=array([16,  1, 38, ..., 12,  7, 10], dtype=int64)>

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_preds)
plt.figure(figsize=(25, 25))
sns.heatmap(cm, annot=True, fmt='g')
plt.show()

# %%
L = 7
W = 7
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel() 
for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title("Prediction={}\n True={}".format(y_preds[i], y_test[i]))
    axes[i].axis('off')
plt.subplots_adjust(wspace=1)
